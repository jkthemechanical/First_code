# %%
# PROGRAM TO DISPLAY DAY FOR THE DATE ENTERED BY USER
day = 0
count = 0
d = m = y = 0
e = 0

d = int(input("Enter Date:"))
m = int(input("Enter Month:"))
y = int(input("Enter Year:"))

if(y==0):e = 1
    
if(m==1):
    if(d<1 or d>31):e=1
elif(m==2):
    if((((y%4)==0) and ((y%100)!=0))  or (((y%4)==0) and ((y%100)==0) and ((y%400)==0))):
        if(d<1 or d>29):e=1
    else:
        if(d<1 or d>28):e=1
elif(m==3):
    if(d<1 or d>31):e=1
elif(m==4):
    if(d<1 or d>30):e=1
elif(m==5):
    if(d<1 or d>31):e=1
elif(m==6):
    if(d<1 or d>30):e=1
elif(m==7):
    if(d<1 or d>31):e=1
elif(m==8):
    if(d<1 or d>31):e=1
elif(m==9):
    if(d<1 or d>30):e=1
elif(m==10):
    if(d<1 or d>31):e=1
elif(m==11):
    if(d<1 or d>30):e=1
elif(m==12):
    if(d<1 or d>31):e=1
else: e=1
        
if(e==1):print("Invalid date")
    

if (y<2006):
    day=1
    #for(int i=2005;i>=y;i--)
    i=2005
    while(i>=y):
        if((((i%4)==0) and ((i%100)!=0))  or (((i%4)==0) and ((i%100)==0) and ((i%400)==0))):
            day -= 2
        else: day -= 1
        i -= 1
else:
    #for (int i=2006;i<=y;i++)
    i=2006
    while(i<=y):
        if((((i%4)==0) and ((i%100)!=0))  or (((i%4)==0) and ((i%100)==0) and ((i%400)==0))):
            count += 1
            day += 1
            i+=1
            continue
        elif(count==1):
            day += 2
            count = 0
            i+=1
        else:
            day += 1
            i+=1

if((((y%4)==0) and ((y%100)!=0))  or (((y%4)==0) and ((y%100)==0) and ((y%400)==0))):
    if (m == 1): None
    elif (m == 2):day+=3
    elif (m == 3):day+=4
    elif (m == 4): None
    elif (m == 5):day+=2
    elif (m == 6):day+=5
    elif (m == 7): None
    elif (m == 8):day+=3
    elif (m == 9):day+=6
    elif (m == 10):day+=1
    elif (m == 11):day+=4
    elif (m == 12):day+=6
else:
    if (m == 1): None
    elif (m == 2):day+=3
    elif (m == 3):day+=3
    elif (m == 4):day-=1
    elif (m == 5):day+=1
    elif (m == 6):day+=4
    elif (m == 7):day-=1
    elif (m == 8):day+=2
    elif (m == 9):day+=5
    elif (m == 10): None
    elif (m == 11):day+=3
    elif (m == 12):day+=5

day+=(d-1)
day%=7
if(day<0):
    day+=7

if (day == 1):print("~~~~~----___Sunday___----~~~~~")
elif (day == 2):print("~~~~~----___Monday___----~~~~~")
elif (day == 3):print("~~~~~----___Tuesday___----~~~~~")
elif (day == 4):print("~~~~~----___Wednesday___----~~~~~")
elif (day == 5):print("~~~~~----___Thursday___----~~~~~")
elif (day == 6):print("~~~~~----___Friday___----~~~~~")
elif (day == 0):print("~~~~~----___Saturday___----~~~~~")
else:print("Error")
# Out:
# Enter Date:1
# Enter Month:1
# Enter Year:1970
# ~~~~~----___Thursday___----~~~~~

# %%
# To find the given year is leap year or not 
yyyy = int(input("Enter year:"))
if((((yyyy%4)==0) and ((yyyy%100)!=0))  or (((yyyy%4)==0) and ((yyyy%100)==0) and ((yyyy%400)==0))):
    print (yyyy, "is a leap year")
else: print (yyyy, "is not a leap year")
print ("End of program")
# Out:
# Enter year:100
# 100 is not a leap year
# End of program
